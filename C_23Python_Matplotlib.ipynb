# %% [markdown]
# <a href="https://colab.research.google.com/github/GIT-REPO-JAGAN/PYTHON-GOOGLE-COLOB/blob/main/C_23Python_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ####Matplot
# https://matplotlib.org/

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
days = np.array([1, 2, 3, 4, 5])

# %%
"""Plan graph"""
plt.plot(days, closing_share_price) # x-axis, y-axis
plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price)
plt.plot(days, min_share_price)
plt.plot(days, max_share_price)
plt.show()

# %%
"""Graph with Titles"""
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price)
plt.plot(days, min_share_price)
plt.plot(days, max_share_price)
plt.title("Shares prices vs Days of the week")  # Title
plt.xlabel("Days")  # X-Axis title
plt.ylabel("Prices (Rs.)") # Y-Axis title

plt.show()

# %% [markdown]
# #### legend

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price)
plt.plot(days, min_share_price)
plt.plot(days, max_share_price)
plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend()

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price")  # Legend text
plt.plot(days, min_share_price, label="Min price")
plt.plot(days, max_share_price, label="Max price")

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend()

plt.show()

# %%
help(plt.legend)
# Out:
# Help on function legend in module matplotlib.pyplot:
#
# legend(*args, **kwargs)
#     Place a legend on the Axes.
#
#     Call signatures::
#
#         legend()
#         legend(handles, labels)
#         legend(handles=handles)
#         legend(labels)
#
#     The call signatures correspond to the following different ways to use
#     this method:
#
#     **1. Automatic detection of elements to be shown in the legend**
#
#     The elements to be added to the legend are automatically determined,
#     when you do not pass in any extra arguments.
#
#     In this case, the labels are taken from the artist. You can specify
#     them either at artist creation or by calling the
#     :meth:`~.Artist.set_label` method on the artist::
#
#         ax.plot([1, 2, 3], label='Inline label')
#         ax.legend()
#
#     or::
#
#         line, = ax.plot([1, 2, 3])
#         line.set_label('Label via method')
#         ax.legend()
#
#     .. note::
# ...

# %%
# X-Axis title
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price")
plt.plot(days, min_share_price, label="Min price")
plt.plot(days, max_share_price, label="Max price")

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=3)  # Legend position

plt.show()

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red')  # Line colour
plt.plot(days, min_share_price, label="Min price")
plt.plot(days, max_share_price, label="Max price")

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed')  # Line style
plt.plot(days, min_share_price, label="Min price")
plt.plot(days, max_share_price, label="Max price")

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed')
plt.plot(days, min_share_price, 'c-.', label="Min price")   # Line style and colour
plt.plot(days, max_share_price, label="Max price")

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o')  # Mark
plt.plot(days, min_share_price, 'cs-.', label="Min price")
plt.plot(days, max_share_price, label="Max price")

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o')
plt.plot(days, min_share_price, label="Min price", 'cs-.')    # Not a right SYntex
plt.plot(days, max_share_price, label="Max price", color='yellow')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)

plt.show()
# Out:
#   File "<ipython-input-21-44187ad7892c>", line 7
#     plt.plot(days, min_share_price, label="Min price", 'cs-.')
#                                                              ^
# SyntaxError: positional argument follows keyword argument

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)
plt.xticks(days)  # Stick to days given

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5)) # Range for y axis

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))
plt.xlim([2, 4])   # Range for x axis

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))
plt.ylim([100, 110])

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))
plt.xlim([2, 4])
plt.ylim([100, 115])

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5)) # Range as numpy array

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))

for x, y in zip(days, closing_share_price):  # Annotation
    plt.annotate(y, (x,y))

plt.show()

# %%
# Lets understand now zip works
list(zip(days, closing_share_price))
# Out:
# [(1, 103), (2, 109), (3, 114), (4, 105), (5, 99)]

# %%
days
# Out:
# array([1, 2, 3, 4, 5])

# %%
closing_share_price
# Out:
# array([103, 109, 114, 105,  99])

# %%
help(plt.annotate)
# Out:
# Help on function annotate in module matplotlib.pyplot:
#
# annotate(text, xy, xytext=None, xycoords='data', textcoords=None, arrowprops=None, annotation_clip=None, **kwargs)
#     Annotate the point *xy* with text *text*.
#
#     In the simplest form, the text is placed at *xy*.
#
#     Optionally, the text can be displayed in another position *xytext*.
#     An arrow pointing from the text to the annotated point *xy* can then
#     be added by defining *arrowprops*.
#
#     Parameters
#     ----------
#     text : str
#         The text of the annotation.
#
#     xy : (float, float)
#         The point *(x, y)* to annotate. The coordinate system is determined
#         by *xycoords*.
#
#     xytext : (float, float), default: *xy*
#         The position *(x, y)* to place the text at. The coordinate system
#         is determined by *textcoords*.
#
#     xycoords : single or two-tuple of str or `.Artist` or `.Transform` or callable, default: 'data'
#
# ...

# %%
zip(days, closing_share_price)

# %%
list(zip(days, closing_share_price))
# Out:
# [(1, 103), (2, 109), (3, 114), (4, 105), (5, 99)]

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))

for x, y in zip(days, closing_share_price):
    plt.annotate(y, (x,y+1))

plt.show()

# %%
help(plt.figure)
# Out:
# Help on function figure in module matplotlib.pyplot:
#
# figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)
#     Create a new figure, or activate an existing figure.
#
#     Parameters
#     ----------
#     num : int or str or `.Figure`, optional
#         A unique identifier for the figure.
#
#         If a figure with that identifier already exists, this figure is made
#         active and returned. An integer refers to the ``Figure.number``
#         attribute, a string refers to the figure label.
#
#         If there is no figure with the identifier or *num* is not given, a new
#         figure is created, made active and returned.  If *num* is an int, it
#         will be used for the ``Figure.number`` attribute, otherwise, an
#         auto-generated integer value is used (starting at 1 and incremented
# ...

# %%
plt.figure(figsize=(8, 6))    # Graph size

closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))

for x, y in zip(days, closing_share_price):
    plt.annotate(y, (x,y+1))

plt.show()

# %%
plt.figure(figsize=(12, 10))

closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))

for x, y in zip(days, closing_share_price):
    plt.annotate(y, (x,y+0.5))

plt.show()

# %%
plt.figure(figsize=(12, 10))

closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=1)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))

for x, y in zip(days, closing_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, min_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, max_share_price):
    plt.annotate(y, (x,y+0.5))

plt.show()

# %%
plt.figure(figsize=(5, 4))

closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=0)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))

for x, y in zip(days, closing_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, min_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, max_share_price):
    plt.annotate(y, (x,y+0.5))

plt.show()

# %% [markdown]
# #### dpi => dots per inches (resolution of the figure)
#
#
# To understand how figsize works  :- figsize = (7,6) and dpi = 80
#
# 7*80 x 6*80 => 560 x 480 pixels

# %%
plt.figure(dpi=100)

closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=0)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))

for x, y in zip(days, closing_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, min_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, max_share_price):
    plt.annotate(y, (x,y+0.5))

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=0)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))

for x, y in zip(days, closing_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, min_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, max_share_price):
    plt.annotate(y, (x,y+0.5))

plt.show()

# %%
plt.figure(figsize=(7, 6), dpi=80)

closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=0)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))

for x, y in zip(days, closing_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, min_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, max_share_price):
    plt.annotate(y, (x,y+0.5))

plt.show()

# %%
list(zip(days, closing_share_price))
# Out:
# [(1, 103), (2, 109), (3, 114), (4, 105), (5, 99)]

# %%
days
# Out:
# array([1, 2, 3, 4, 5])

# %%
closing_share_price
# Out:
# array([103, 109, 114, 105,  99])

# %%
plt.figure(figsize=(7, 6), dpi=80)

closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=0)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))

plt.annotate(closing_share_price[0], (days[0], closing_share_price[0]))

plt.show()

# %%
plt.figure(figsize=(7, 6), dpi=80)

closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=0)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))

for x, y in zip(days, closing_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, min_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, max_share_price):
    plt.annotate(y, (x,y+0.5))

# plt.savefig("shares.png")  # Use to save file from Local

"""Use to download from google colob"""
from google.colab import files
files.download("shares.png")

plt.show()

# %%
help(plt.savefig)
# Out:
# Help on function savefig in module matplotlib.pyplot:
#
# savefig(*args, **kwargs)
#     Save the current figure.
#
#     Call signature::
#
#       savefig(fname, *, dpi='figure', format=None, metadata=None,
#               bbox_inches=None, pad_inches=0.1,
#               facecolor='auto', edgecolor='auto',
#               backend=None, **kwargs
#              )
#
#     The available output formats depend on the backend being used.
#
#     Parameters
#     ----------
#     fname : str or path-like or binary file-like
#         A path, or a Python file-like object, or
#         possibly some backend-dependent object such as
#         `matplotlib.backends.backend_pdf.PdfPages`.
#
#         If *format* is set, it determines the output format, and the file
#         is saved as *fname*.  Note that *fname* is used verbatim, and there
#         is no attempt to make the extension, if any, of *fname* match
#         *format*, and no extension is appended.
#
# ...

# %%
# Background Style
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.figure(figsize=(7, 6), dpi=80)

plt.style.use('fivethirtyeight')

closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=0)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))

for x, y in zip(days, closing_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, min_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, max_share_price):
    plt.annotate(y, (x,y+0.5))

#plt.savefig("shares.png")
plt.show()

# %%
plt.figure(figsize=(7, 6), dpi=80)

plt.style.use('classic')

closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
days = np.array([1, 2, 3, 4, 5])

plt.plot(days, closing_share_price,label="Closing price", color='red', linestyle='dashed', marker='o', markerfacecolor='grey')
plt.plot(days, min_share_price, '-.cs', label="Min price")
plt.plot(days, max_share_price, label="Max price", color='yellow', marker='^', markerfacecolor='black')

plt.title("Shares prices vs Days of the week")
plt.xlabel("Days")
plt.ylabel("Prices (Rs.)")
plt.legend(loc=0)
plt.xticks(days)
plt.yticks(np.arange(90, 125, 5))

for x, y in zip(days, closing_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, min_share_price):
    plt.annotate(y, (x,y+0.5))

for x, y in zip(days, max_share_price):
    plt.annotate(y, (x,y+0.5))

# plt.savefig("shares.png")
plt.show()

# %%
help(plt.annotate)
# Out:
# Help on function annotate in module matplotlib.pyplot:
#
# annotate(text, xy, *args, **kwargs)
#     Annotate the point *xy* with text *text*.
#
#     In the simplest form, the text is placed at *xy*.
#
#     Optionally, the text can be displayed in another position *xytext*.
#     An arrow pointing from the text to the annotated point *xy* can then
#     be added by defining *arrowprops*.
#
#     Parameters
#     ----------
#     text : str
#         The text of the annotation.
#
#     xy : (float, float)
#         The point *(x, y)* to annotate. The coordinate system is determined
#         by *xycoords*.
#
#     xytext : (float, float), default: *xy*
#         The position *(x, y)* to place the text at. The coordinate system
#         is determined by *textcoords*.
#
#     xycoords : str or `.Artist` or `.Transform` or callable or (float, float), default: 'data'
#
#         The coordinate system that *xy* is given in. The following types
#         of values are supported:
#
# ...

# %% [markdown]
# #### Subplots

# %%
# add_subplot of figure object

# %%
fig = plt.figure(figsize=(8, 6))
fig.add_subplot(2, 2, 1) # rows, cols, position
fig.add_subplot(2, 2, 2)
fig.add_subplot(2, 2, 3)
fig.add_subplot(2, 2, 4)

plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
fig.add_subplot(2, 2, 1) # rows, cols, position
fig.add_subplot(2, 2, 3)
fig.add_subplot(2, 2, 4)

plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
fig.add_subplot(2, 2, 1) # rows, cols, position
fig.add_subplot(2, 2, 4)

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
data = [10, 8, 4, -2, 6, 9]
days = np.array([1, 2, 3, 4, 5])

fig = plt.figure(figsize=(8, 6))

fig.add_subplot(2, 2, 1)
plt.plot(days, min_share_price, color='red')
plt.plot(days, max_share_price)

fig.add_subplot(2, 2, 2)
plt.plot(days, max_share_price)

fig.add_subplot(2, 2, 3)
plt.plot(days, closing_share_price)

fig.add_subplot(2, 2, 4)
plt.plot(data)

plt.show()

# %%
# Not a right approch
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
data = [10, 8, 4, -2, 6, 9]
days = np.array([1, 2, 3, 4, 5])

fig = plt.figure(figsize=(8, 6))

fig.add_subplot(2, 2, 1)
fig.add_subplot(2, 2, 2)
fig.add_subplot(2, 2, 3)
fig.add_subplot(2, 2, 4)

plt.plot(days, min_share_price, color='red')
plt.plot(days, max_share_price)
plt.plot(days, closing_share_price)
plt.plot(data)

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
data = [10, 8, 4, -2, 6, 9]
days = np.array([1, 2, 3, 4, 5])

fig = plt.figure(figsize=(8, 6))

fig.add_subplot(2, 2, 1)
plt.plot(days, min_share_price, color='red')

fig.add_subplot(2, 2, 2)
plt.plot(days, max_share_price)

fig.add_subplot(2, 2, 3)
plt.plot(days, closing_share_price)

fig.add_subplot(2, 2, 4)
plt.plot(data)

plt.show()

# %%
closing_share_price = np.array([103, 109, 114, 105, 99])
min_share_price = np.array([102, 105, 111, 105, 97])
max_share_price = np.array([105, 112, 117, 113, 106])
data = [10, 8, 4, -2, 6, 9]
days = np.array([1, 2, 3, 4, 5])

fig = plt.figure(figsize=(8, 6))

fig.add_subplot(2, 2, 1)
plt.plot(days, min_share_price, color='red')

fig.add_subplot(2, 2, 2)
plt.plot(days, max_share_price)

fig.add_subplot(2, 2, 3)
plt.plot(days, closing_share_price)

fig.add_subplot(2, 2, 4)
plt.plot([-3, -2, -1, 0, 1, 2], data)

plt.show()

# %%
# subplots of plt

# %%
plt.subplots(2, 2) # rows, cols
plt.show()

# %%
plt.subplots(2, 3) # rows, cols
plt.show()

# %%
plt.subplots(1, 2) # rows, cols
plt.show()

# %%
p = plt.subplots(2, 2)

# %%
print(p)
# Out:
# (<Figure size 640x480 with 4 Axes>, array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object))

# %%
type(p)
# Out:
# tuple

# %%
len(p)
# Out:
# 2

# %%
print(p[0])
# Out:
# Figure(640x480)

# %%
print(p[1])
# Out:
# [[<AxesSubplot:> <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:>]]

# %%
p[1]
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
fig, ax_plots = plt.subplots(2, 2)

# %%
print(fig)
# Out:
# Figure(640x480)

# %%
print(ax_plots)
# Out:
# [[<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]]

# %%
fig, ax_plots = plt.subplots(2, 2)
ax_plots[0, 0].plot(days, closing_share_price)
ax_plots[0, 1].plot(days, min_share_price)
ax_plots[1, 0].plot(days, max_share_price)

plt.show()

# %%
fig, ax_plots = plt.subplots(2, 2)
ax_plots[0, 0].plot(days, closing_share_price)
ax_plots[0, 1].plot(days, min_share_price)
ax_plots[1, 0].plot(days, max_share_price)
ax_plots[1, 1].plot(data)

plt.show()

# %% [markdown]
# #### Special graphs

# %%
# Bar plot

# %%
countries = ['India', 'China', 'US', 'Aus', 'Canada']
population = [142, 140, 90, 20, 60]

plt.bar(countries, population)
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-39f510d45dca> in <cell line: 1>()
# ----> 1 plt.style.use()
#
# TypeError: use() missing 1 required positional argument: 'style'

# %%
help(plt.bar)
# Out:
# Help on function bar in module matplotlib.pyplot:
#
# bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)
#     Make a bar plot.
#
#     The bars are positioned at *x* with the given *align*\ment. Their
#     dimensions are given by *height* and *width*. The vertical baseline
#     is *bottom* (default 0).
#
#     Many parameters can take either a single value applying to all bars
#     or a sequence of values, one for each bar.
#
#     Parameters
#     ----------
#     x : float or array-like
#         The x coordinates of the bars. See also *align* for the
#         alignment of the bars to the coordinates.
#
#     height : float or array-like
#         The height(s) of the bars.
#
#     width : float or array-like, default: 0.8
#         The width(s) of the bars.
#
#     bottom : float or array-like, default: 0
#         The y coordinate(s) of the bars bases.
#
#     align : {'center', 'edge'}, default: 'center'
# ...

# %%
countries = ['India', 'China', 'US', 'Aus', 'Canada']
population = [142, 140, 90, 20, 60]

plt.barh(countries, population)
plt.show()

# %%
# pie chart

# %%
ipl_teams = ['MI', 'RCB', 'CSK', 'KKR', 'RR']
cups = [5, 0, 5, 2, 1]

plt.pie(cups, labels=ipl_teams)
plt.show()

# %%
help(plt.pie)
# Out:
# Help on function pie in module matplotlib.pyplot:
#
# pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, normalize=True, hatch=None, data=None)
#     Plot a pie chart.
#
#     Make a pie chart of array *x*.  The fractional area of each wedge is
#     given by ``x/sum(x)``.
#
#     The wedges are plotted counterclockwise, by default starting from the
#     x-axis.
#
#     Parameters
#     ----------
#     x : 1D array-like
#         The wedge sizes.
#
#     explode : array-like, default: None
#         If not *None*, is a ``len(x)`` array which specifies the fraction
#         of the radius with which to offset each wedge.
#
#     labels : list, default: None
#         A sequence of strings providing the labels for each wedge
#
#     colors : array-like, default: None
# ...

# %%
help(plt.style.use)
# Out:
# Help on function use in module matplotlib.style.core:
#
# use(style)
#     Use Matplotlib style settings from a style specification.
#
#     The style name of 'default' is reserved for reverting back to
#     the default style settings.
#
#     .. note::
#
#        This updates the `.rcParams` with the settings from the style.
#        `.rcParams` not defined in the style are kept.
#
#     Parameters
#     ----------
#     style : str, dict, Path or list
#         A style specification. Valid options are:
#
#         +------+-------------------------------------------------------------+
#         | str  | The name of a style or a path/URL to a style file. For a    |
#         |      | list of available style names, see `style.available`.       |
#         +------+-------------------------------------------------------------+
#         | dict | Dictionary with valid key/value pairs for                   |
# ...

# %%
plt.style.use('default')

# %%
ipl_teams = ['MI', 'RCB', 'CSK', 'KKR', 'RR']
cups = [5, 0, 5, 2, 1]

plt.pie(cups, labels=ipl_teams)
plt.show()

# %%
ipl_teams = ['MI', 'RCB', 'CSK', 'KKR', 'RR']
cups = [5, 0, 5, 2, 1]

plt.pie(cups, labels=ipl_teams, explode=[.01,.2,.3,.4,.05])
plt.show()

# %% [markdown]
# #### Scatterplot

# %%
exp = [1, 2, 5, 7, 10, 12, 15, 20, 25, 30]
sal = [10000, 15000, 22000, 25000, 30000, 35000, 44000, 50000, 60000, 80000]

plt.scatter(exp, sal)
plt.show()

# %%
x = np.random.randint(1, 50, (100,))

# %%
x
# Out:
# array([26, 25,  8, 39, 39, 45, 22, 22, 31, 28, 48, 30, 27, 10, 17, 41, 42,
#         3,  5, 18, 29, 29, 33, 21, 37, 48, 12, 34, 20, 35, 15,  4,  4, 28,
#        26, 17, 46, 49, 31, 39, 38, 46, 17, 47, 17, 36, 19, 24, 10,  7, 19,
#        17, 48, 33, 31, 17,  6, 11, 20, 22, 10, 30, 37, 16, 32, 27,  1, 25,
#        20,  2, 27, 29, 17, 26, 23, 39, 28, 38,  4, 23, 49, 43,  9, 23, 48,
#        28, 42,  2,  2,  8, 18, 41, 19, 46, 37, 46, 46, 19, 38, 33])

# %%
plt.scatter(y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-855e6f1db3da> in <cell line: 1>()
# ----> 1 plt.scatter(y)
#       2 plt.show()
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
y = np.arange(0, 100)

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# #### subplot of plt

# %%
years = [2017, 2018, 2019, 2020, 2021, 2022]
sales = [40000, 42000, 45000, 34000, 47000, 50000]
profits = [7, 9, 11, 5, 13, 15]

# %%
plt.subplot(2, 1, 1) # rows, cols, position
plt.scatter(years, profits)

plt.subplot(2, 1, 2)
plt.bar(years, sales)

plt.show()
